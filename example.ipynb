# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelWithLMHead

from environment import Chat
from actor_critic_net import ActorCritic
from agent import PPO
from utils import trainer, Predictor

# %%
# set device to cpu or cuda
if torch.backends.mps.is_available():
    device = torch.device('mps') 
    print("Device set to : mps")
elif(torch.cuda.is_available()): 
    device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(device)))
else:
    device = torch.device('cpu')
    print("Device set to : cpu")
# Out:
# Device set to : mps

# %%
tokenizer = AutoTokenizer.from_pretrained('huggingtweets/elonmusk')
model = AutoModelWithLMHead.from_pretrained('huggingtweets/elonmusk').to(device)
feedback_pipe = pipeline('sentiment-analysis',
                        model="cardiffnlp/twitter-roberta-base-sentiment",
                        tokenizer="cardiffnlp/twitter-roberta-base-sentiment",
                        return_all_scores=True, 
                        device=device)

# %%
####### initialize environment hyperparameters ######

max_ep_len = 20    # max timesteps in one episode
obs_base = ['I think Tesla is', 
            'I think dogecoin is', 
            'I think BTC is', 
            'I think Twitter is', 
            'I think ElonMusk is']    # init observations that will use to run the episodes

################ PPO hyperparameters ################
epochs = 50    # update policy for K epochs
eps_clip = 0.2    # clip parameter for PPO
gamma = 1    # discount factor

lr_actor = 5e-6    # learning rate for actor network
lr_critic = 5e-6    # learning rate for critic network

################## Trainer Setting ##################
max_training_timesteps = 30000
print_freq = 100
update_timestep = max_ep_len * 100
save_model_freq = max_ep_len * 100
checkpoint_path = "PPO_model.pth"
eval_obs = 'I think Tesla is'    # observation use to check performance after model update

# %%
env = Chat(llm=model, tokenizer=tokenizer, reward_pipe=feedback_pipe, obs_base=obs_base, max_gen_len=max_ep_len)
policy = ActorCritic(model).to(device)
ppo_agent = PPO(policy=policy, lr_actor=lr_actor, lr_critic=lr_critic, gamma=gamma, K_epochs=epochs, eps_clip=eps_clip)

# %% [markdown]
# ### train with RLHF

# %%
trainer(
    env,
    ppo_agent,
    max_training_timesteps=max_training_timesteps,
    max_ep_len=max_ep_len,
    update_timestep=update_timestep,
    save_model_timestep=save_model_freq,
    print_freq=print_freq,
    checkpoint_path=checkpoint_path,
    eval_obs=eval_obs
)
# Out:
# Episode : 5 		 Timestep : 100 		 Average Reward : 1.65
# Episode : 12 		 Timestep : 200 		 Average Reward : 0.69
# Episode : 20 		 Timestep : 300 		 Average Reward : 0.57
# Episode : 25 		 Timestep : 400 		 Average Reward : 1.16
# Episode : 32 		 Timestep : 500 		 Average Reward : 1.09
# Episode : 38 		 Timestep : 600 		 Average Reward : 1.98
# Episode : 43 		 Timestep : 700 		 Average Reward : 3.29
# Episode : 51 		 Timestep : 800 		 Average Reward : 1.45
# Episode : 58 		 Timestep : 900 		 Average Reward : 1.12
# Episode : 64 		 Timestep : 1000 		 Average Reward : 2.55
# Episode : 70 		 Timestep : 1100 		 Average Reward : 2.33
# Episode : 78 		 Timestep : 1200 		 Average Reward : 0.66
# Episode : 85 		 Timestep : 1300 		 Average Reward : 0.56
# Episode : 92 		 Timestep : 1400 		 Average Reward : 1.98
# Episode : 100 		 Timestep : 1500 		 Average Reward : 1.94
# Episode : 106 		 Timestep : 1600 		 Average Reward : 1.79
# Episode : 112 		 Timestep : 1700 		 Average Reward : 0.36
# Episode : 119 		 Timestep : 1800 		 Average Reward : 1.81
# Episode : 125 		 Timestep : 1900 		 Average Reward : 1.7
# generated sentence: I think Tesla is from California … Tesla bought California whole … Tesla is now operating in 53 states through California AGI,
#  score: 0.0995375495404005
# Episode : 130 		 Timestep : 2000 		 Average Reward : 1.31
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 136 		 Timestep : 2100 		 Average Reward : 3.11
# Episode : 142 		 Timestep : 2200 		 Average Reward : 3.25
# Episode : 148 		 Timestep : 2300 		 Average Reward : 2.46
# Episode : 153 		 Timestep : 2400 		 Average Reward : 0.45
# Episode : 160 		 Timestep : 2500 		 Average Reward : 0.1
# Episode : 166 		 Timestep : 2600 		 Average Reward : 0.61
# Episode : 171 		 Timestep : 2700 		 Average Reward : 3.22
# Episode : 179 		 Timestep : 2800 		 Average Reward : 2.77
# Episode : 186 		 Timestep : 2900 		 Average Reward : 1.43
# Episode : 193 		 Timestep : 3000 		 Average Reward : 2.72
# Episode : 199 		 Timestep : 3100 		 Average Reward : 0.27
# Episode : 205 		 Timestep : 3200 		 Average Reward : 2.92
# Episode : 212 		 Timestep : 3300 		 Average Reward : 0.58
# Episode : 218 		 Timestep : 3400 		 Average Reward : 3.77
# Episode : 223 		 Timestep : 3500 		 Average Reward : 2.21
# Episode : 229 		 Timestep : 3600 		 Average Reward : 0.89
# Episode : 235 		 Timestep : 3700 		 Average Reward : 1.21
# Episode : 241 		 Timestep : 3800 		 Average Reward : 4.63
# Episode : 247 		 Timestep : 3900 		 Average Reward : 0.54
# generated sentence: I think Tesla is doing it right, given 2018 launch date.<|endoftext|>
#  score: 0.037577704060822725
# Episode : 253 		 Timestep : 4000 		 Average Reward : 0.14
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 258 		 Timestep : 4100 		 Average Reward : 0.23
# Episode : 266 		 Timestep : 4200 		 Average Reward : 1.75
# Episode : 271 		 Timestep : 4300 		 Average Reward : 3.17
# Episode : 278 		 Timestep : 4400 		 Average Reward : 1.43
# Episode : 285 		 Timestep : 4500 		 Average Reward : 1.1
# Episode : 292 		 Timestep : 4600 		 Average Reward : 0.61
# Episode : 298 		 Timestep : 4700 		 Average Reward : 1.69
# Episode : 304 		 Timestep : 4800 		 Average Reward : 2.0
# Episode : 311 		 Timestep : 4900 		 Average Reward : 3.08
# Episode : 318 		 Timestep : 5000 		 Average Reward : 0.08
# Episode : 325 		 Timestep : 5100 		 Average Reward : 1.55
# Episode : 334 		 Timestep : 5200 		 Average Reward : 2.73
# Episode : 341 		 Timestep : 5300 		 Average Reward : 1.55
# Episode : 349 		 Timestep : 5400 		 Average Reward : 1.05
# Episode : 355 		 Timestep : 5500 		 Average Reward : 1.03
# Episode : 364 		 Timestep : 5600 		 Average Reward : 1.58
# Episode : 370 		 Timestep : 5700 		 Average Reward : 1.61
# Episode : 377 		 Timestep : 5800 		 Average Reward : 2.13
# Episode : 384 		 Timestep : 5900 		 Average Reward : 0.29
# generated sentence: I think Tesla is 100% off the hook for these costs, so maybe a little higher.<|endoftext|>
#  score: 0.2516932226717472
# Episode : 390 		 Timestep : 6000 		 Average Reward : 1.88
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 399 		 Timestep : 6100 		 Average Reward : 2.0
# Episode : 405 		 Timestep : 6200 		 Average Reward : 2.16
# Episode : 411 		 Timestep : 6300 		 Average Reward : 0.02
# Episode : 419 		 Timestep : 6400 		 Average Reward : 1.36
# Episode : 427 		 Timestep : 6500 		 Average Reward : 0.49
# Episode : 433 		 Timestep : 6600 		 Average Reward : 0.12
# Episode : 441 		 Timestep : 6700 		 Average Reward : 0.2
# Episode : 448 		 Timestep : 6800 		 Average Reward : 0.47
# Episode : 454 		 Timestep : 6900 		 Average Reward : 2.7
# Episode : 460 		 Timestep : 7000 		 Average Reward : 0.53
# Episode : 467 		 Timestep : 7100 		 Average Reward : 0.74
# Episode : 476 		 Timestep : 7200 		 Average Reward : 1.22
# Episode : 485 		 Timestep : 7300 		 Average Reward : 1.04
# Episode : 492 		 Timestep : 7400 		 Average Reward : 2.31
# Episode : 500 		 Timestep : 7500 		 Average Reward : 0.55
# Episode : 508 		 Timestep : 7600 		 Average Reward : 0.5
# Episode : 514 		 Timestep : 7700 		 Average Reward : 1.54
# Episode : 521 		 Timestep : 7800 		 Average Reward : 2.62
# Episode : 529 		 Timestep : 7900 		 Average Reward : 2.63
# generated sentence: I think Tesla is crazy for having zero passenger car (LAX) fleet on par with Tesla. It takes a while
#  score: 5.510630011558533
# Episode : 537 		 Timestep : 8000 		 Average Reward : 1.56
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 545 		 Timestep : 8100 		 Average Reward : 2.37
# Episode : 553 		 Timestep : 8200 		 Average Reward : 2.1
# Episode : 560 		 Timestep : 8300 		 Average Reward : 0.69
# Episode : 566 		 Timestep : 8400 		 Average Reward : 2.35
# Episode : 572 		 Timestep : 8500 		 Average Reward : 0.39
# Episode : 579 		 Timestep : 8600 		 Average Reward : 0.2
# Episode : 589 		 Timestep : 8700 		 Average Reward : 0.97
# Episode : 596 		 Timestep : 8800 		 Average Reward : 2.29
# Episode : 606 		 Timestep : 8900 		 Average Reward : 1.48
# Episode : 613 		 Timestep : 9000 		 Average Reward : 2.85
# Episode : 619 		 Timestep : 9100 		 Average Reward : 1.17
# Episode : 627 		 Timestep : 9200 		 Average Reward : 2.69
# Episode : 634 		 Timestep : 9300 		 Average Reward : 2.53
# Episode : 641 		 Timestep : 9400 		 Average Reward : 1.8
# Episode : 649 		 Timestep : 9500 		 Average Reward : 0.12
# Episode : 655 		 Timestep : 9600 		 Average Reward : 1.21
# Episode : 663 		 Timestep : 9700 		 Average Reward : 1.84
# Episode : 672 		 Timestep : 9800 		 Average Reward : 0.59
# Episode : 678 		 Timestep : 9900 		 Average Reward : 0.08
# generated sentence: I think Tesla is a company that is taking great step in the right direction, building great new companies, trying hard to
#  score: 0.01639006193727255
# Episode : 687 		 Timestep : 10000 		 Average Reward : 2.09
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode :
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 1881 		 Timestep : 22100 		 Average Reward : 1.24
# Episode : 1892 		 Timestep : 22200 		 Average Reward : 0.97
# Episode : 1901 		 Timestep : 22300 		 Average Reward : 0.87
# Episode : 1911 		 Timestep : 22400 		 Average Reward : 2.16
# Episode : 1924 		 Timestep : 22500 		 Average Reward : 1.61
# Episode : 1935 		 Timestep : 22600 		 Average Reward : 2.94
# Episode : 1951 		 Timestep : 22700 		 Average Reward : 1.2
# Episode : 1966 		 Timestep : 22800 		 Average Reward : 0.56
# Episode : 1977 		 Timestep : 22900 		 Average Reward : 0.68
# Episode : 1986 		 Timestep : 23000 		 Average Reward : 0.71
# Episode : 1995 		 Timestep : 23100 		 Average Reward : 0.26
# Episode : 2006 		 Timestep : 23200 		 Average Reward : 2.67
# Episode : 2015 		 Timestep : 23300 		 Average Reward : 1.45
# Episode : 2027 		 Timestep : 23400 		 Average Reward : 2.3
# Episode : 2034 		 Timestep : 23500 		 Average Reward : 0.86
# Episode : 2043 		 Timestep : 23600 		 Average Reward : 1.5
# Episode : 2056 		 Timestep : 23700 		 Average Reward : 1.05
# Episode : 2072 		 Timestep : 23800 		 Average Reward : 1.29
# Episode : 2084 		 Timestep : 23900 		 Average Reward : 2.57
# generated sentence: I think Tesla is doing a good job at bringing Tesla Tesla Enterprise up to date enough to enable the demand of Tesla EV
#  score: 0.017894264310598373
# Episode : 2099 		 Timestep : 24000 		 Average Reward : 0.33
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 2113 		 Timestep : 24100 		 Average Reward : 0.39
# Episode : 2125 		 Timestep : 24200 		 Average Reward : 0.78
# Episode : 2139 		 Timestep : 24300 		 Average Reward : 1.5
# Episode : 2152 		 Timestep : 24400 		 Average Reward : 0.72
# Episode : 2167 		 Timestep : 24500 		 Average Reward : 0.93
# Episode : 2179 		 Timestep : 24600 		 Average Reward : 2.41
# Episode : 2192 		 Timestep : 24700 		 Average Reward : 1.9
# Episode : 2200 		 Timestep : 24800 		 Average Reward : 0.89
# Episode : 2211 		 Timestep : 24900 		 Average Reward : 1.58
# Episode : 2222 		 Timestep : 25000 		 Average Reward : 2.28
# Episode : 2231 		 Timestep : 25100 		 Average Reward : 0.59
# Episode : 2244 		 Timestep : 25200 		 Average Reward : 1.8
# Episode : 2253 		 Timestep : 25300 		 Average Reward : 0.07
# Episode : 2263 		 Timestep : 25400 		 Average Reward : 2.18
# Episode : 2276 		 Timestep : 25500 		 Average Reward : 1.37
# Episode : 2291 		 Timestep : 25600 		 Average Reward : 1.8
# Episode : 2302 		 Timestep : 25700 		 Average Reward : 0.19
# Episode : 2314 		 Timestep : 25800 		 Average Reward : 1.51
# Episode : 2326 		 Timestep : 25900 		 Average Reward : 0.98
# generated sentence: I think Tesla is actually doing the Tesla factory work<|endoftext|>
#  score: 0.14074384234845638
# Episode : 2336 		 Timestep : 26000 		 Average Reward : 0.88
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 2348 		 Timestep : 26100 		 Average Reward : 2.74
# Episode : 2360 		 Timestep : 26200 		 Average Reward : 2.1
# Episode : 2374 		 Timestep : 26300 		 Average Reward : 0.38
# Episode : 2387 		 Timestep : 26400 		 Average Reward : 0.89
# Episode : 2397 		 Timestep : 26500 		 Average Reward : 1.46
# Episode : 2413 		 Timestep : 26600 		 Average Reward : 1.21
# Episode : 2426 		 Timestep : 26700 		 Average Reward : 1.22
# Episode : 2435 		 Timestep : 26800 		 Average Reward : 1.55
# Episode : 2447 		 Timestep : 26900 		 Average Reward : 0.94
# Episode : 2458 		 Timestep : 27000 		 Average Reward : 0.47
# Episode : 2471 		 Timestep : 27100 		 Average Reward : 1.33
# Episode : 2485 		 Timestep : 27200 		 Average Reward : 1.87
# Episode : 2497 		 Timestep : 27300 		 Average Reward : 0.79
# Episode : 2505 		 Timestep : 27400 		 Average Reward : 1.3
# Episode : 2517 		 Timestep : 27500 		 Average Reward : 1.47
# Episode : 2529 		 Timestep : 27600 		 Average Reward : 0.07
# Episode : 2539 		 Timestep : 27700 		 Average Reward : 0.53
# Episode : 2549 		 Timestep : 27800 		 Average Reward : 3.26
# Episode : 2564 		 Timestep : 27900 		 Average Reward : 2.58
# generated sentence: I think Tesla is too big, already. Tesla has gone up almost 70% income a year from Tesla (2.
#  score: 0.3380007669329643
# Episode : 2577 		 Timestep : 28000 		 Average Reward : 1.19
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------
# Episode : 2589 		 Timestep : 28100 		 Average Reward : 1.84
# Episode : 2602 		 Timestep : 28200 		 Average Reward : 1.29
# Episode : 2623 		 Timestep : 28300 		 Average Reward : 0.87
# Episode : 2639 		 Timestep : 28400 		 Average Reward : 1.05
# Episode : 2651 		 Timestep : 28500 		 Average Reward : 0.83
# Episode : 2665 		 Timestep : 28600 		 Average Reward : 1.18
# Episode : 2680 		 Timestep : 28700 		 Average Reward : 1.44
# Episode : 2690 		 Timestep : 28800 		 Average Reward : 1.11
# Episode : 2698 		 Timestep : 28900 		 Average Reward : 0.39
# Episode : 2709 		 Timestep : 29000 		 Average Reward : 2.63
# Episode : 2725 		 Timestep : 29100 		 Average Reward : 1.77
# Episode : 2735 		 Timestep : 29200 		 Average Reward : 3.18
# Episode : 2744 		 Timestep : 29300 		 Average Reward : 2.77
# Episode : 2757 		 Timestep : 29400 		 Average Reward : 0.63
# Episode : 2773 		 Timestep : 29500 		 Average Reward : 0.72
# Episode : 2782 		 Timestep : 29600 		 Average Reward : 1.6
# Episode : 2796 		 Timestep : 29700 		 Average Reward : 2.19
# Episode : 2810 		 Timestep : 29800 		 Average Reward : 1.47
# Episode : 2821 		 Timestep : 29900 		 Average Reward : 1.2
# generated sentence: I think Tesla is obviously telling the truth," said Brookard.<|endoftext|>
#  score: 0.8268853276968002
# Episode : 2833 		 Timestep : 30000 		 Average Reward : 2.15
# --------------------------------------------------------------------------------------------
# saving model at : PPO_model.pth
# model saved
# --------------------------------------------------------------------------------------------

# %% [markdown]
# ### Inference

# %%
env = Chat(llm=model, tokenizer=tokenizer, reward_pipe=feedback_pipe, obs_base=obs_base, max_gen_len=max_ep_len)
policy = ActorCritic(model, temperature=1, top_p=1, top_k=0).to(device)

# %%
predictor = Predictor(env, policy)
predictor.load_model(checkpoint_path)

# %%
predictor.predict('I think Tesla is')
# Out:
# 'I think Tesla is bad enough of it …<|endoftext|>'
